# %% [markdown]
# In this notebook I show how to compare different repertoires through the models' scores to obtain specificity scores and the AUROCs of specificity (Fig. 4,S5,S6)

# %%
rootf = FOLDER ## place here the folder where you save all the folders of the git ##

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.family'] = ['Garuda']
mpl.rcParams['font.serif'] = ['Garuda-Oblique']
import csv
curr_float = np.float32
curr_int = np.int16

def overlap_seqs(list1,list2):
    overlap=[]
    for i in range(len(list1)):
        if list1[i] in list2:
            overlap.append(list1[i])
    return overlap


def convert_number(seqs): # convert to numbers already aligned seqs
    aa = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V',  'W', 'Y','-']
    aadict = {aa[k]: k for k in range(len(aa))}
    msa_num = np.array(list(map(lambda x: [aadict[y] for y in x], seqs[0:])), dtype=curr_int, order="c")
    
    return msa_num

def convert_letter(seqs_n): # convert to numbers already aligned seqs
    aa = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V',  'W', 'Y','-']
    aadictinv = {k: aa[k] for k in range(len(aa))} 
    seqs=[]
    if type(seqs_n[0]) == curr_int:
        seqs.append(''.join([aadictinv[e] for e in seqs_n]))
    else:
        for t in range(len(seqs_n)):
            seqs.append(''.join([aadictinv[e] for e in seqs_n[t]]))
    return seqs

def uniqueIndexes(l):
    seen = set()
    res = []
    for i, n in enumerate(l):
        if n not in seen:
            res.append(i)
            seen.add(n)
    return res

#%matplotlib inline
import sys, os, pickle
sys.path.append('/home/barbara/.local/lib/python3.6/site-packages/')
sys.path.append(rootf + '/PGM/source/')
sys.path.append(rootf + '/PGM/utilities/')
sys.path.append(rootf + '/Align_utils/')
from common_imports import set_num_threads
set_num_threads(1) # Set the number of cores. Must be executed before importing numpy&numba.
import rbm,utilities
import Proteins_utils, RBM_utils, utilities, sequence_logo, plots_utils

from sklearn import metrics
import matplotlib.pyplot as plt

import matplotlib as mpl
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib import patches
from pandas.plotting import table

mpl.rcParams['font.family'] = ['Garuda']
mpl.rcParams['font.serif'] = ['Garuda-Oblique']

def countX(lst, x): 
    return lst.count(x) 

listpep1 = ['WT', 'NA', 'MUC16ID', 'MUC16WT', 'CR'];
listpep2 = ['WT', 'NA', 'MUC16ID', 'MUC16WT', 'CR'];
listpep3 = ['NA', 'CR'];
listpep4 = ['WT', 'NA', 'CR'];
listpep5 = ['NA', 'CR'];
listpep6 = ['NA1', 'NA2', 'CR1', 'CR2'];
listpep7 = ['NA','CR']; 
listpep=[listpep1,listpep2,listpep3,listpep4,listpep5,listpep6,listpep7];
# Out:
# In /home/barbara/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/barbara/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/barbara/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/barbara/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/barbara/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/barbara/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/barbara/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/barbara/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# /home/barbara/.local/lib/python3.6/site-packages/numba/errors.py:137: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)
# /home/barbara/Barbara_Bravi/rbm/Notebooks/rbm_tcell/PGM/source/numba_utilities.py:1124: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float32, 2d, F), array(float32, 2d, A))
#   dmean_v_dw = np.dot(s1.T, V)
# /home/barbara/Barbara_Bravi/rbm/Notebooks/rbm_tcell/PGM/source/numba_utilities.py:1125: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float32, 2d, F), array(float32, 2d, A))
#   dvar_e_dw = np.dot(s2.T, V)
# /home/barbara/Barbara_Bravi/rbm/Notebooks/rbm_tcell/PGM/source/numba_utilities.py:1126: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float32, 2d, F), array(float32, 2d, A))
#   tmp3 = np.dot(s3.T, V)
# /home/barbara/Barbara_Bravi/rbm/Notebooks/rbm_tcell/PGM/source/numba_utilities.py:961: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float32, 1d, A), array(float32, 2d, A))
#   mean_V = np.dot(weights, V) / sum_weights

# %% [markdown]
# The first step is the estimation of each sequence's abundance and likelihood under each condition (model). For illustration, the model considered here is the simple RBM (with aligned sequences).

# %%
remback=0 ## this variable tells whether the background probability should be substracted

def ll_seq_pp(data_seqs_val_3w_n,ptnm,pepm,Nm_w,hu,l12,remback):
    nm = rootf + '/Models/CDR3out_pt' + str(int(ptnm)) + '_' + pepm + '_' + str(int(Nm_w)) + 'w/model_' + str(hu) + '_' + str(l12) + '.data'
    RBM = RBM_utils.loadRBM(nm)
    
    if remback==1:
        nmd0 = rootf + '/Models/CDR3out_pt' + str(int(ptnm)) + '_day0/model_' + str(hu) + '_' + str(l12) + '.data'
        RBM_d0 = RBM_utils.loadRBM(nmd0)
        ll =  RBM.likelihood(data_seqs_val_3w_n) - RBM_d0.likelihood(data_seqs_val_3w_n)
    else:
        ll = RBM.likelihood(data_seqs_val_3w_n)
		
    return ll

path_in = rootf + '/Data/CDR3'
n_v = 19 # Number of visible units; = # sites in alignment.
n_h = 25 # Number of hidden units.
hu = n_h

l12 = 0.1
TS = 80
import pandas as pd

def countX(lst, x): 
    return lst.count(x) 

listpep1 = ['WT', 'NA', 'MUC16ID', 'MUC16WT', 'CR'];
listpep2 = ['WT', 'NA', 'MUC16ID', 'MUC16WT', 'CR'];
listpep3 = ['NA', 'CR'];
listpep4 = ['WT', 'NA', 'CR'];
listpep5 = ['NA', 'CR'];
listpep6 = ['NA1', 'NA2', 'CR1', 'CR2'];
listpep7 = ['NA','CR']; 
listpep=[listpep1,listpep2,listpep3,listpep4,listpep5,listpep6,listpep7];

# Lists of log-likelihoods under different models for validation sequences ##

list_3w = [1,2,3,4,5,6,7]

N=19
q=21
N_model=N
hu = 25
l12 = 0.1

for pp in list_3w:
    
    ptn=pp
    nd = rootf + '/Data/Count-weighted/Validation/CDR3fasta_pt' + str(int(ptn)) + '_full_3w_02.fasta'
    data_val_3w_n = Proteins_utils.load_FASTA(nd, with_labels=False, remove_insertions=False, drop_duplicates=False)
    data_val_3w = convert_letter(data_val_3w_n)
    
    listll=[]
    listfc=[]
    for r in range(len(listpep[pp-1])):
        pep=listpep[pp-1][r]
        ll = ll_seq_pp(data_val_3w_n,ptn,pep,3,hu, l12,remback)
        
        summary = pd.read_csv(rootf + '/Data/summary_pt'+str(ptn)+'_'+ pep + '.tsv', sep='\t', low_memory=False)
        mult3w = (summary['Mult 3w (rep)'].values)
        multd0 = (summary['Mult day0 (rep)'].values)
        
        fc = np.zeros(len(data_val_3w_n)) 
        ps = 0.5
        seqs_g = list(summary['CDR3_gap'].values.astype(np.str))
        for s0 in range(len(data_val_3w)):
            s=data_val_3w[s0]
            if s in seqs_g:
                ind = seqs_g.index(s)
                if remback==0:
                    fc[s0] = np.log10((mult3w[ind]+ps))
                else:
                    fc[s0] = np.log10((mult3w[ind]+ps)/(multd0[ind]+ps))
                    
        listll.append(ll)
        listfc.append(fc)
    
    ztot=zip(data_val_3w,*listll)
    
    nr=rootf + '/Data/Specificity_tables/RBM/rank_LL_pt' + str(int(ptn)) + '_auroc.txt'    
    with open(nr, 'w') as out_f:
        title= 'CDR3' + '\t'
        for r in range(len(listpep[pp-1])):
            pep=listpep[pp-1][r]
            title = title + pep + '\t'
        out_f.write(title + '\n')
        writer = csv.writer(out_f, delimiter='\t')
        writer.writerows(ztot)  
        
    ztot=zip(data_val_3w,*listfc)
    
    nr=rootf + '/Data/Specificity_tables/rank_LL_pt' + str(int(ptn)) + '_log10fc.txt'    
    with open(nr, 'w') as out_f:
        title= 'CDR3' + '\t'
        for r in range(len(listpep[pp-1])):
            pep=listpep[pp-1][r]
            title = title + pep + '\t'
        out_f.write(title + '\n')
        writer = csv.writer(out_f, delimiter='\t')
        writer.writerows(ztot)

# %% [markdown]
# I add the same estimation of the sequence likelihood under different models for the Left-Right version of RBM

# %%
amino_acids = 'ACDEFGHIKLMNPQRSTVWY'
aadict = {amino_acids[k]: k for k in range(len(amino_acids))} 

max_L = 19
max_depth = max_L

features = []
for aa in amino_acids:
    features += [['a' + aa + str(L)] for L in range(max_depth)]
    features += [['a' + aa + str(L)] for L in range(-max_depth, 0)] # features for encoding

features_r = []
for aa in amino_acids:
    features_r += [['a\t' + aa + '\t' + str(L)] for L in range(max_depth)]
    features_r += [['a\t' + aa + '\t' + str(L)] for L in range(-max_depth, 0)]  # features for writing

feature_dict = {tuple(f): i for i, f in enumerate(features)}
feature_dict_inv = {i:f for i, f in enumerate(features)}


remback=0 ## this variable tells whether the background probability should be substracted

def ll_seq_pp_LR(data_seqs_val_3w_n,ptnm,pepm,Nm_w,hu,l12,remback):
     
    nm = rootf + '/Models/CDR3out_pt' + str(int(ptnm)) + '_' + pepm + '_' + str(int(Nm_w)) + 'w/model_' + str(hu) + '_' + str(l12) + '_LR.data'
    RBM = RBM_utils.loadRBM(nm)
    
    if remback==1:
        nmd0 = rootf + '/Models/CDR3out_pt' + str(int(ptnm)) + '_day0/model_' + str(hu) + '_' + str(l12) + '_LR.data'
        RBM_d0 = RBM_utils.loadRBM(nmd0)
        ll =  RBM.likelihood(data_seqs_val_3w_n.astype(np.int16)) - RBM_d0.likelihood(data_seqs_val_3w_n.astype(np.int16))
    else:
        ll = RBM.likelihood(data_seqs_val_3w_n.astype(np.int16),recompute_Z=True)
		
    return ll

path_in = rootf + '/Data/CDR3'

# Lists of LL under different models for validation sequences

list_3w = [1,2,3,4,5,6,7]
n_v = 19 # Number of visible units; = # sites in alignment.
n_h = 25 # Number of hidden units.
hu = n_h
TS = 80
N_model=n_v
l12 = 0.1

for pp in list_3w:
    
    ptn=pp
    nd = rootf + '/Data/Count-weighted/Validation/CDR3fasta_pt' + str(int(ptn)) + '_full_3w_02.fasta'
    data_val_3w_n = Proteins_utils.load_FASTA(nd, with_labels=False, remove_insertions=False, drop_duplicates=False)
    data_val_3w = convert_letter(data_val_3w_n)
    
    seqs_gapless=[]
    seqs=[]
    for r in range(len(listpep[pp-1])):
        pep=listpep[pp-1][r]
        summary = pd.read_csv(rootf + '/Data/summary_pt'+str(ptn)+'_' + pep + '.tsv', sep='\t', low_memory=False)
        seqs_gapless0 = list(summary['CDR3'])
        subset = uniqueIndexes(seqs_gapless0)
        summary1=summary.loc[subset,:]
        seqs0=list(summary1['CDR3_gap'].values)
        seqs_gapless0=list(summary1['CDR3'].values)
        seqs_gapless += seqs_gapless0
        seqs += seqs0
        
    data_seqs_val_3w = []
    for t in range(len(data_val_3w)):
        ij = seqs.index(data_val_3w[t])
        seq = seqs_gapless[ij]
        seq_feature_lsts = [['a' + aa + str(i)] for i, aa in enumerate(seq)]
        seq_feature_lsts += [['a' + aa + str(-1-i)] for i, aa in enumerate(seq[::-1])]
        seq_features = list(set([feature_dict[tuple(f)] for f in seq_feature_lsts if tuple(f) in feature_dict]))
        length_input=len(features)
        data=np.array(seq_features)
        data_enc = np.zeros(length_input, dtype=np.int8)
        for i in range(len(data)): data_enc[data[i]] = 1
        data_seqs_val_3w.append(list(data_enc))  
        
    data_seqs_val_3w_n = np.array(data_seqs_val_3w).astype(np.int16)
    
    listll=[]
    listfc=[]
    for r in range(len(listpep[pp-1])):
        pep=listpep[pp-1][r]
        ll = ll_seq_pp_LR(data_seqs_val_3w_n,ptn,pep,3,hu, l12,remback)
                    
        listll.append(ll)
    
    ztot=zip(data_val_3w,*listll)
    
    nr=rootf + '/Data/Specificity_tables/RBM_LR/rank_LL_pt' + str(int(ptn)) + '_auroc.txt'    
    with open(nr, 'w') as out_f:
        title= 'CDR3' + '\t'
        for r in range(len(listpep[pp-1])):
            pep=listpep[pp-1][r]
            title = title + pep + '\t'
        out_f.write(title + '\n')
        writer = csv.writer(out_f, delimiter='\t')
        writer.writerows(ztot)
# Out:
# Mismatch dimensions (200, 25), [10, 25], reinitializating I
# Mismatch dimensions (200, 760, 2), [10, 760, 2], reinitializating I
# Mismatch dimensions (200, 25), [10, 25], reinitializating I
# Mismatch dimensions (200, 760, 2), [10, 760, 2], reinitializating I

# %% [markdown]
# The models' scores are next put together to obtain the AUROCs of specificity. I produce, for each type of model and for each sample, a list of true labels and predicted scores that allow me to plot the ROC and calculate the AUROC.

# %%
beginl=1 
writer = pd.ExcelWriter(rootf + '/Data/Specificity_tables/summary_aurocs.xlsx', engine = 'xlsxwriter')
## Here one chooses the folder for which one in interested in the scores ##

for fold_model in ['RBM','RBM_LR','SONIA','PWM']:
    for pp in range(1,8):
        aurocp = np.zeros((len(listpep[pp-1]),len(listpep[pp-1])))
        print('Patient')
        print(pp)

        ptn=pp
        for r in range(len(listpep[pp-1])):

            pep=listpep[pp-1][r]  

            print(pep)

            seq1=[]
            i=1
            with open(rootf + '/Data/Count-weighted/Validation/CDR3fasta_pt' + str(pp) + '_' + pep + '_3w_02.fasta') as f:
                for line in f:
                    if i % 2 == 0:
                        linesplit = line.strip().split('\t')
                        seq1.append(linesplit[0])
                    i=i+1

            ## Read the fold change and use it as label for 'specific expansion' ##

            seq2fc=[]
            seqfc=[]
            NF = rootf + '/Data/Specificity_tables/rank_LL_pt' + str(int(ptn)) + '_log10fc.txt'
            if fold_model == 'SONIA': ## For Sonia, we need the list of only sequences at P_gen non-zero
                NF = rootf + '/Data/Specificity_tables/' + fold_model + '/rank_LL_pt' + str(int(ptn)) + '_log10FC.txt'
            with open(NF) as f: 
                for line in f:
                    linesplit = line.strip().split('\t')
                    nogap2=linesplit[0].replace(' ','')
                    seq2fc.append(nogap2)
                    seqfc.append(linesplit[beginl:len(linesplit)])    

            PL=np.zeros(len(seq2fc)-1)
            for l in range(1,len(seq2fc)):
                new = np.array(seqfc[l]).astype(float) + np.random.normal(loc=0.0, scale=0.0001, size=len(seqfc[l]))
                if np.argmax(new) == r:
                    PL[l-1]=1
            labels=np.copy(PL)

            ## Here I read the scores assigned by a given model ##

            seq2=[]
            seqll=[]
            with open(rootf + '/Data/Specificity_tables/' + fold_model + '/rank_LL_pt' + str(int(ptn)) + '_auroc.txt') as f: 
                for line in f:
                    linesplit = line.strip().split('\t')
                    nogap2=linesplit[0].replace(' ','')
                    seq2.append(nogap2)
                    seqll.append(linesplit[beginl:len(linesplit)])

            PLL=np.zeros(len(seq2)-1)
            for l in range(1,len(seq2)):
                listot=[]
                listdiff=[]
                for i in range(r):
                    listot.append(float(seqll[l][i]))
                    listdiff.append(abs(float(seqll[l][r])-float(seqll[l][i])))
                for i in range(r+1,len(seqll[l])):
                    listot.append(float(seqll[l][i]))
                    listdiff.append(abs(float(seqll[l][r])-float(seqll[l][i])))
                score = float(seqll[l][r]) - listot[np.argmin(listdiff)]
                PLL[l-1] = score

            scores = np.copy(PLL) 

            fpr, tpr, thresholds = metrics.roc_curve(labels, scores)
            auroc = metrics.auc(fpr, tpr)
            print(auroc)

            datao = {'Labels': labels.astype(int),
                    'Scores': scores
                                    }
            df = pd.DataFrame(datao, columns = ['Labels','Scores'])
            df1 = pd.DataFrame({'AUROC':[auroc]}, columns = ['AUROC'])
            df2 = pd.concat([df,df1], axis=1)

            df2.to_excel(writer, sheet_name = fold_model + '_pat_' + str(pp) + '_' + pep, index=0)
            
            
            ## Here the calculation of pairwise AUROCs is shown for RBM ##
            if pp in [1,2,4,6] and fold_model in ['RBM']:

                for s in range(r+1,len(listpep[pp-1])):
                    pep1=listpep[pp-1][s]
                    seq1n=[]
                    i=1
                    with open(rootf + '/Data/Count-weighted/Validation/CDR3fasta_pt' + str(pp) + '_' + pep1 + '_3w_02.fasta') as f:
                        for line in f:
                            if i % 2 == 0:
                                linesplit = line.strip().split('\t')
                                seq1n.append(linesplit[0])
                            i=i+1

                    TLp=[]
                    PLp=[]
                    for l in range(1,len(seq2fc)):
                        if seq2fc[l] in seq1 or seq2fc[l] in seq1n: # I limit the choice to seqs. that are in at least one of the samples #
                            if seqfc[l][r] > seqfc[l][s]:
                                TLp.append(1)
                            else:
                                TLp.append(0)
                            PLp.append(float(seqll[l][r])-float(seqll[l][s]))

                    fpr, tpr, thresholds = metrics.roc_curve(TLp, PLp)
                    aurocp[r,s] = metrics.auc(fpr, tpr)

                mat = (aurocp + np.transpose(aurocp)) 
                df = pd.DataFrame(mat).T
                df.to_excel(writer, sheet_name = fold_model + '_pat_' + str(pp) + '_pairwise', index=0)
        
writer.save()
# Out:
# Patient
# 1
# WT
# 0.8522335359871238
# NA
# 0.7351842303856093
# MUC16ID
# 0.8178598939600088
# MUC16WT
# 0.840832443069381
# CR
# 0.7447726996790983
# Patient
# 2
# WT
# 0.8981206182370167
# NA
# 0.9188736349571015
# MUC16ID
# 0.9322029342685471
# MUC16WT
# 0.8480535231968622
# CR
# 0.8481764309517386
# Patient
# 3
# NA
# 0.9116684177661831
# CR
# 0.9117787981906236
# Patient
# 4
# WT
# 0.8248318598267704
# NA
# 0.8754752023810551
# CR
# 0.803954940478803
# Patient
# 5
# NA
# 0.8946863126968495
# CR
# 0.8946159821507361
# Patient
# 6
# NA1
# 0.8829426631550626
# NA2
# 0.8447200727736015
# CR1
# 0.870147998661264
# CR2
# 0.908364180881641
# Patient
# 7
# NA
# 0.6920891114051028
# CR
# 0.6915991059828066
# Patient
# 1
# WT
# 0.8377541866157359
# NA
# 0.7733563340892513
# MUC16ID
# 0.8507346487356089
# MUC16WT
# 0.8652611134187429
# CR
# 0.7304608333426922
# Patient
# 2
# WT
# 0.9022857848163023
# NA
# 0.9472991383380189
# MUC16ID
# 0.936583926525369
# MUC16WT
# 0.8469322117650517
# CR
# 0.8598534376054889
# Patient
# 3
# NA
# 0.9119973477300614
# CR
# 0.9119138971643851
# Patient
# 4
# WT
# 0.7470160644295967
# NA
# 0.8811407301455467
# CR
# 0.881900552696873
# Patient
# 5
# NA
# 0.8977849113768223
# CR
# 0.8976401442671144
# Patient
# 6
# NA1
# 0.8643264826350578
# NA2
# 0.7784500567255384
# CR1
# 0.8565123682561091
# CR2
# 0.8666771187511373
# Patient
# 7
# NA
# 0.7204164825537709
# CR
# 0.72127106526629
# Patient
# 1
# WT
# 0.7595945079117158
# NA
# 0.7630133596282412
# MUC16ID
# 0.7829891158001443
# MUC16WT
# 0.790016157136807
# CR
# 0.625587564828654
# Patient
# 2
# WT
# 0.8698151531731694
# NA
# 0.83845984489585
# MUC16ID
# 0.7910599245478476
# MUC16WT
# 0.8305714086462436
# CR
# 0.8743910089033322
# Patient
# 3
# NA
# 0.8852888887404056
# CR
# 0.8848589727514171
# Patient
# 4
# WT
# 0.671916535875405
# NA
# 0.8143410889650827
# CR
# 0.8163015736977872
# Patient
# 5
# NA
# 0.8778680527262853
# CR
# 0.877570130018607
# Patient
# 6
# NA1
# 0.8731814408853136
# NA2
# 0.8220128758265419
# CR1
# 0.8625700019673963
# CR2
# 0.8545166870601428
# Patient
# 7
# NA
# 0.723755182307853
# CR
# 0.7239992783962318
# Patient
# 1
# WT
# 0.7152334214542686
# NA
# 0.7110340134685464
# MUC16ID
# 0.7398051425339587
# MUC16WT
# 0.7268275933756572
# CR
# 0.6048443751448233
# Patient
# 2
# WT
# 0.8797411552492718
# NA
# 0.7953737926082305
# MUC16ID
# 0.7179757156843859
# MUC16WT
# 0.7845647939431641
# CR
# 0.653388339615228
# Patient
# 3
# NA
# 0.8173893875412173
# CR
# 0.8175662109503647
# Patient
# 4
# WT
# 0.578509113761641
# NA
# 0.767438711630318
# CR
# 0.776222982336414
# Patient
# 5
# NA
# 0.8229786280512865
# CR
# 0.8226792078404714
# Patient
# 6
# NA1
# 0.7743738986658408
# NA2
# 0.7737760967915173
# CR1
# 0.7959552547168949
# CR2
# 0.7916391091080337
# Patient
# 7
# NA
# 0.722957104847034
# CR
# 0.7233402146589387

# %% [markdown]
# These blocks are now to visualize the results on specificity predictions, directly reading the values of 'scores' and 'labels' already saved. For illustration, I read the RBM, RBM-LR, SONIA model scores for patients 3 and 7 peptide = NA as in figure 4A,C

# %%
listpep1 = ['WT', 'NA', 'MUC16ID', 'MUC16WT', 'CR'];
listpep2 = ['WT', 'NA', 'MUC16ID', 'MUC16WT', 'CR'];
listpep3 = ['NA', 'CR'];
listpep4 = ['WT', 'NA', 'CR'];
listpep5 = ['NA', 'CR'];
listpep6 = ['NA1', 'NA2', 'CR1', 'CR2'];
listpep7 = ['NA','CR']; 
listpep=[listpep1,listpep2,listpep3,listpep4,listpep5,listpep6,listpep7];

sheet_names=[]
for fold_model in ['RBM', 'RBM_LR', 'SONIA']:
    for pp in range(1,8):
        for r in range(len(listpep[pp-1])):
            pep=listpep[pp-1][r]
            sheet_names.append(fold_model + '_pat_' + str(pp) + '_' + pep)
        
file = pd.read_excel(rootf + '/Data/Specificity_tables/summary_aurocs.xlsx', sheet_name = sheet_names)

# %%
fold_model = 'RBM'
pp = 7
pep = 'NA'
file1 = file[fold_model + '_pat_' + str(pp) + '_' + pep]
labels = list(file1['Labels'].values)
scores = list(file1['Scores'].values)

scores_p = [scores[p] for p in range(len(scores)) if labels[p]==1]/np.log(10)
scores_n = [scores[p] for p in range(len(scores)) if labels[p]==0]/np.log(10)

import seaborn as sns
fig,ax=plt.subplots()
fig.set_figwidth(6)
fig.set_figheight(4)

w=5
colors = ['DarkGreen', 'black']
sns.distplot(scores_p, norm_hist = True,  hist_kws={'edgecolor':'MidnightBlue'}, color = colors[0], hist = True,kde=False, bins=int(230/5), rug=False, label = 'Specific to '+ pep, ax = ax)
sns.distplot(scores_n, norm_hist = True, hist_kws={'edgecolor':'DimGray'}, hist = True, bins=int(200/5), kde=False, color = colors[1], label = 'Unspecific', ax = ax)

s2=18
ax.set_xlabel(r'RBM score $\mathcal{S}^{NA}_{\rm spec}$', fontsize = s2)
ax.set_ylabel('Density', fontsize = s2)
plt.legend( fontsize = s2-2)
ax.set_title('Pt' + str(pp) + ' TRB response', fontsize = s2)
ax.tick_params(axis='both', which='major', labelsize = s2)

# %%
fold_model = 'RBM'
pp = 3
pep = 'NA'
file1 = file[fold_model + '_pat_' + str(pp) + '_' + pep]
labels = list(file1['Labels'].values)
scores = list(file1['Scores'].values)
scores_p = [scores[p] for p in range(len(scores)) if labels[p]==1]/np.log(10)
scores_n = [scores[p] for p in range(len(scores)) if labels[p]==0]/np.log(10)

fig,ax=plt.subplots()
fig.set_figwidth(6)
fig.set_figheight(4)

w=5
colors = ['DarkViolet', 'black']
sns.distplot(scores_p, norm_hist = True,  hist_kws={'edgecolor':'MidnightBlue'}, color = colors[0], hist = True,kde=False, bins=int(230/5), rug=False, label = 'Specific to NA', ax = ax)
sns.distplot(scores_n, norm_hist = True, hist_kws={'edgecolor':'DimGray'}, hist = True, bins=int(200/5), kde=False, color = colors[1], label = 'Unspecific', ax = ax)

s2=18
ax.set_xlabel(r'RBM score $\mathcal{S}^{NA}_{\rm spec}$', fontsize = s2)
ax.set_ylabel('Density', fontsize = s2)
plt.legend( fontsize = s2-2)
ax.set_title('Pt3 TRB response', fontsize = s2)
ax.tick_params(axis='both', which='major', labelsize = s2)

# %%
fold_list=['RBM', 'RBM_LR', 'SONIA']
tech = ['RBM', 'RBM-LR', 'SONIA']
remback_list= [0,0,0]
s0=18

for pp in [3,7]:
    fig, axf = plt.subplots(1,3)
    fig.set_figwidth(15)
    fig.set_figheight(4)
    plt.subplots_adjust(wspace = 0.3, hspace = 0.5)
    for f in range(3):
        fold_model = fold_list[f]
        for r in range(1):
            
            file1 = file[fold_model + '_pat_' + str(pp) + '_' + pep]
            labels = list(file1['Labels'].values)
            scores = list(file1['Scores'].values)

            ax2 = axf[f]
            fpr, tpr, thresholds = metrics.roc_curve(labels, scores)
            auroc = metrics.auc(fpr, tpr)
            ax2.plot(fpr,tpr,lw=3,color='k')
            ax2.set_title(tech[f], fontsize=s0+2)
            ax2.set_xticks([0,0.5,1])
            ax2.set_yticks([0,0.5,1])
            ax2.tick_params(axis='both', which='major', labelsize=s0-1)
            ax2.text(0.4, 0.15, 'AUROC = ' + format(metrics.auc(fpr, tpr), '.2f'), fontsize=s0-1)
            ax2.plot([0, 1], [0, 1], transform=ax2.transAxes, color='DimGray', linestyle='--')
            if f==0:
                ax2.set_xlabel('Fraction of unspecific responders', fontsize=s0-2)
                ax2.set_ylabel('Fraction of specific responders', fontsize=s0-2)

# %%
## Summary plot over all samples for RBM (fig. 4D) ## 
fold_model = 'RBM'

list_NA = ['NA', 'NA1', 'NA2']
list_MUC16 = ['MUC16ID']
list_XRM = ['CR', 'CR1', 'CR2']
list_WT = ['WT']
list_MUC16WT = ['MUC16WT']

list_pat = []
list_pep = []
list_auc = []
for pp in range(1,8):
    for r in range(len(listpep[pp-1])):
        pep=listpep[pp-1][r]
        file1 = file[fold_model + '_pat_' + str(pp) + '_' + pep]
        list_pat.append(pp)
        list_pep.append(pep)
        list_auc.append((file1['AUROC'].values)[0])
    
name_tech = 'RBM AUROC of specificity'
datao = {'Patient': list_pat,
        'Peptide': list_pep,
        name_tech: list_auc,
        }
df = pd.DataFrame (datao, columns = ['Patient','Peptide', name_tech])

auroc_xrm = list(df[df['Peptide'].isin(list_XRM)][name_tech].values)
auroc_wt_muc = list(df[df['Peptide'].isin(list_WT)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16WT)][name_tech].values)
auroc_na_muc = list(df[df['Peptide'].isin(list_NA)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16)][name_tech].values)

names_na_muc=['Pt1 NA','Pt2 NA','Pt3 NA','Pt4 NA','Pt5 NA','Pt6 NA1', 'Pt6 NA2', 'Pt7 NA', 'Pt1 MUC16','Pt2 MUC16']
names_na = names_na_muc[:-2]
names_wt_muc=['Pt1 WT','Pt2 WT','Pt4 WT', 'Pt1 MUC16WT','Pt2 MUC16WT']
names_wt=names_wt_muc[:-2]
names_xrm=['Pt1 CR','Pt2 CR','Pt3 CR','Pt4 CR','Pt5 CR','Pt6 CR1', 'Pt6 CR2', 'Pt7 CR']

colors3 = list(np.repeat(['DarkGoldenRod'],len(names_na_muc))) + list(np.repeat(['Maroon'],len(names_wt_muc))) + list(np.repeat(['CadetBlue'],len(names_xrm)))
colors3.append('Gray')
s2=16
sc=2
fig,ax=plt.subplots()
fig.set_figheight(5)
fig.set_figwidth(12)
fig.subplots_adjust(bottom = 0.4)

meth = names_na_muc + names_wt_muc + names_xrm + ['Control']
meth_val = np.array(auroc_na_muc + auroc_wt_muc + auroc_xrm + [0.514])

x_pos = np.arange(len(meth_val))
x_pos = np.arange(0,2*len(meth_val),2)
ax.bar(x_pos, meth_val, alpha=1, edgecolor='k', align = 'center', capsize=sc, color = colors3)
ax.set_ylim(0.4, 1)
ax.set_xticks(x_pos)
ax.set_ylabel(name_tech, fontsize = 14)
ax.tick_params(axis='both', which='major', labelsize = 14)
ax.set_xticklabels(meth, rotation = 30, fontsize = 12, ha='right', rotation_mode = 'anchor')
plt.axhline(y=0.5, color='k', linestyle='--')

# %%
## Scatter plot of comparison (fig. 4E) ##

list_meth = ['RBM','RBM_LR','SONIA']
list_meth_lab = ['RBM','RBM-LR','SONIA']
auc_val_all=[]
for fold_model in list_meth:

    list_pat = []
    list_pep = []
    list_auc = []
    for pp in range(1,8):
        for r in range(len(listpep[pp-1])):
            pep=listpep[pp-1][r]
            file1 = file[fold_model + '_pat_' + str(pp) + '_' + pep]
            list_pat.append(pp)
            list_pep.append(pep)
            list_auc.append((file1['AUROC'].values)[0])

    name_tech = 'AUROC of specificity'
    datao = {'Patient': list_pat,
            'Peptide': list_pep,
            name_tech: list_auc,
            }
    df = pd.DataFrame (datao, columns = ['Patient','Peptide', name_tech])

    auroc_xrm = list(df[df['Peptide'].isin(list_XRM)][name_tech].values)
    auroc_wt_muc = list(df[df['Peptide'].isin(list_WT)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16WT)][name_tech].values)
    auroc_na_muc = list(df[df['Peptide'].isin(list_NA)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16)][name_tech].values)

    meth_val = np.array(auroc_na_muc + auroc_wt_muc + auroc_xrm)
    
    auc_val_all.append(meth_val)
    
auc_val = auc_val_all[0]
auc_val_sonia= auc_val_all[2]
auc_val_LR = auc_val_all[1]


fig, axes = plt.subplots(1,2)
fig.set_figheight(5)
fig.set_figwidth(10)
fig.subplots_adjust(bottom = 0.4, hspace=0.01)

ax=axes[0]
y = auc_val
x = auc_val_LR
sc=70

datao = {'Patient': list_pat,
        'Peptide': list_pep,
        name_tech: x,
        }

df = pd.DataFrame (datao, columns = ['Patient','Peptide', name_tech])
auroc_xrm = list(df[df['Peptide'].isin(list_XRM)][name_tech].values)
auroc_wt_muc = list(df[df['Peptide'].isin(list_WT)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16WT)][name_tech].values)
auroc_na_muc = list(df[df['Peptide'].isin(list_NA)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16)][name_tech].values)
meth_val1 = np.array(auroc_na_muc + auroc_wt_muc + auroc_xrm) 
meth = names_na_muc + names_wt_muc + names_xrm

datao = {'Patient': list_pat,
        'Peptide': list_pep,
        name_tech: y,
        }

df = pd.DataFrame (datao, columns = ['Patient','Peptide', name_tech])

auroc_xrm = list(df[df['Peptide'].isin(list_XRM)][name_tech].values)
auroc_wt_muc = list(df[df['Peptide'].isin(list_WT)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16WT)][name_tech].values)
auroc_na_muc = list(df[df['Peptide'].isin(list_NA)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16)][name_tech].values)
meth_val2 = np.array(auroc_na_muc + auroc_wt_muc + auroc_xrm) 
meth = names_na_muc + names_wt_muc + names_xrm

ax.scatter(meth_val1[:10], meth_val2[:10], c = 'DarkGoldenRod', edgecolors='k', s = sc)
ax.scatter(meth_val1[10:15], meth_val2[10:15], c = 'Maroon', edgecolors='k', s = sc)
ax.scatter(meth_val1[15:], meth_val2[15:], c = 'CadetBlue', edgecolors='k', s = sc)

s2=16
ax.set_title('AUROC of specificity', fontsize = s2+2)
ax.set_xlabel('RBM-LR', fontsize = s2)
ax.set_ylabel('RBM', fontsize = s2)
ax.tick_params(axis='both', which='major', labelsize = s2)
ax.set_xlim([0.5,1])
ax.set_ylim([0.5,1])
ax.set_aspect('equal')
ax.plot([0, 1], [0, 1], transform=ax.transAxes, color='k', linestyle='--')

ax=axes[1]
y = auc_val
x = auc_val_sonia

datao = {'Patient': list_pat,
        'Peptide': list_pep,
        name_tech: x,
        }

df = pd.DataFrame (datao, columns = ['Patient','Peptide', name_tech])

auroc_xrm = list(df[df['Peptide'].isin(list_XRM)][name_tech].values)
auroc_wt_muc = list(df[df['Peptide'].isin(list_WT)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16WT)][name_tech].values)
auroc_na_muc = list(df[df['Peptide'].isin(list_NA)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16)][name_tech].values)
meth_val1 = np.array(auroc_na_muc + auroc_wt_muc + auroc_xrm) 
meth = names_na_muc + names_wt_muc + names_xrm

datao = {'Patient': list_pat,
        'Peptide': list_pep,
        name_tech: y,
        }

df = pd.DataFrame (datao, columns = ['Patient','Peptide', name_tech])

auroc_xrm = list(df[df['Peptide'].isin(list_XRM)][name_tech].values)
auroc_wt_muc = list(df[df['Peptide'].isin(list_WT)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16WT)][name_tech].values)
auroc_na_muc = list(df[df['Peptide'].isin(list_NA)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16)][name_tech].values)
meth_val2 = np.array(auroc_na_muc + auroc_wt_muc + auroc_xrm) 
meth = names_na_muc + names_wt_muc + names_xrm

ax.scatter(meth_val1[:10], meth_val2[:10], c = 'DarkGoldenRod', edgecolors='k', s = sc)
ax.scatter(meth_val1[10:15], meth_val2[10:15], c = 'Maroon', edgecolors='k', s = sc)
ax.scatter(meth_val1[15:], meth_val2[15:], c = 'CadetBlue', edgecolors='k', s = sc)

s2=16
ax.set_xlabel('SONIA', fontsize = s2)
ax.tick_params(axis='both', which='major', labelsize = s2)
ax.set_xlim([0.5,1])
ax.set_ylim([0.5,1])
ax.set_yticklabels([])
ax.set_aspect('equal')

ax.plot([0, 1], [0, 1], transform=ax.transAxes, color='k', linestyle='--')

# %%
## Check of specificity score with cross-reactive clones: crosss-reactivitiy to NA/CR in pat. 3 ##
beginl=1 
fold_model = 'RBM'

ptn=3
pep='NA'
summary = pd.read_csv(rootf + '/Data/summary_pt'+str(ptn)+'_'+ pep +'.tsv', sep='\t', low_memory=False)
seqs = list(summary['CDR3'])
subset = uniqueIndexes(seqs)
summary1=summary.loc[subset,:]
exp_id = list(summary1[summary1['Exp. significant'] == 1]['CDR3_gap'].values)
summary0=summary1[summary1['Exp. significant'] == 1]
mult_id = np.log10(summary0['Mult 3w (rep)'].values+0.5) - np.log10(summary0['Mult day0 (rep)'].values+0.5)

ptn=3
pep='CR'
summary = pd.read_csv(rootf + '/Data/summary_pt'+str(ptn)+'_'+ pep +'.tsv', sep='\t', low_memory=False)
seqs = list(summary['CDR3'])
subset = uniqueIndexes(seqs)
summary1=summary.loc[subset,:]
exp_xrm = list(summary1[summary1['Exp. significant'] == 1]['CDR3_gap'].values)
summary0=summary1[summary1['Exp. significant'] == 1]
mult_xrm = np.log10(summary0['Mult 3w (rep)'].values+0.5) - np.log10(summary0['Mult day0 (rep)'].values+0.5)

over = overlap_seqs(exp_id,exp_xrm)
ind_over = [exp_id.index(i) for i in over]
ind_over_x = [exp_xrm.index(i) for i in over]
over = overlap_seqs([exp_id[r] for r in ind_over],[exp_xrm[r] for r in ind_over_x])
ind_over = [exp_id.index(i) for i in over]
ind_over_x = [exp_xrm.index(i) for i in over]

ptn=3
seq2=[]
seqll=[]
with open(rootf + '/Data/Specificity_tables/' + fold_model + '/rank_LL_pt' + str(int(ptn)) + '_auroc.txt') as f: 
    for line in f:
        linesplit = line.strip().split('\t')
        nogap2=linesplit[0].replace(' ','')
        seq2.append(nogap2)
        seqll.append(linesplit[beginl:len(linesplit)])
        
ss = [exp_id[r] for r in ind_over]
sco=[]
for s in ss:
    ii = seq2.index(s)
    sco.append(float(seqll[ii][0])-float(seqll[ii][1]))
    
x=mult_id[ind_over]
y=mult_xrm[ind_over_x]

z = abs(np.array(sco)/np.log(10))

fig,ax=plt.subplots()
fig.set_figwidth(5)
fig.set_figheight(5)
s2=16

cmap = ax.scatter(x, y, c = z, s = 100, edgecolor='k', cmap='Blues');
cbar = plt.colorbar(mappable=cmap, shrink = 0.7)
cbar.ax.tick_params(labelsize=s2)
cbar.set_ticks([4,8,12])

plt.subplots_adjust(bottom = 0.1)
ax.set_xlabel('Log fold change upon NA', fontsize=s2)
ax.set_ylabel('Log fold change upon CR', fontsize=s2)

ax.dist = 12
ax.set_xticks([1,2,3,4])
ax.set_yticks([1,2,3,4])
ax.set_ylim([0.8,4.5])
ax.set_xlim([0.8,4.5])

ax.set_title(r'Highly cross-reactive |$\mathcal{S}_{\rm spec}^{NA}$|', loc='right', fontsize=s2+2)
ax.tick_params(axis='both', which='major', labelsize = s2)
ax.set_aspect(1)

# %% [markdown]
# Finally, here I produce a heatmap matrix that summarizes the AUROCs for all the samples and modelling approaches

# %%
list_NA = ['NA', 'NA1', 'NA2']
list_MUC16 = ['MUC16ID']
list_XRM = ['CR', 'CR1', 'CR2']
list_WT = ['WT']
list_MUC16WT = ['MUC16WT']
list_meth = ['RBM','RBM_LR','SONIA']
list_meth_lab = ['RBM','RBM-LR','SONIA']
meth_val_all=[]
for fold_model in list_meth:
    
    sheet_names=[]
    for pp in range(1,8):
        for r in range(len(listpep[pp-1])):
            pep=listpep[pp-1][r]
            sheet_names.append(fold_model + '_pat_' + str(pp) + '_' + pep)
    
    file = pd.read_excel(rootf + '/Data/Specificity_tables/summary_aurocs.xlsx', sheet_name = sheet_names)
    
    list_pat = []
    list_pep = []
    list_auc = []
    for pp in range(1,8):
        for r in range(len(listpep[pp-1])):
            pep=listpep[pp-1][r]
            file1 = file[fold_model + '_pat_' + str(pp) + '_' + pep]
            list_pat.append(pp)
            list_pep.append(pep)
            list_auc.append((file1['AUROC'].values)[0])

    name_tech = 'AUROC of specificity'
    datao = {'Patient': list_pat,
            'Peptide': list_pep,
            name_tech: list_auc,
            }
    df = pd.DataFrame (datao, columns = ['Patient','Peptide', name_tech])

    auroc_xrm = list(df[df['Peptide'].isin(list_XRM)][name_tech].values)
    auroc_wt_muc = list(df[df['Peptide'].isin(list_WT)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16WT)][name_tech].values)
    auroc_na_muc = list(df[df['Peptide'].isin(list_NA)][name_tech].values) + list(df[df['Peptide'].isin(list_MUC16)][name_tech].values)

    meth_val = np.array(auroc_na_muc + auroc_wt_muc + auroc_xrm)
    
    meth_val_all.append(meth_val)

# %%
names_na_muc=['Pt1 NA','Pt2 NA','Pt3 NA','Pt4 NA','Pt5 NA','Pt6 NA1', 'Pt6 NA2', 'Pt7 NA', 'Pt1 MUC16','Pt2 MUC16']
names_na = names_na_muc[:-2]
names_wt_muc = ['Pt1 WT','Pt2 WT','Pt4 WT', 'Pt1 MUC16WT','Pt2 MUC16WT']
names_wt = names_wt_muc[:-2]
names_xrm = ['Pt1 CR','Pt2 CR','Pt3 CR','Pt4 CR','Pt5 CR','Pt6 CR1', 'Pt6 CR2', 'Pt7 CR']

meth = names_na_muc + names_wt_muc + names_xrm + ['Average']

meth_val_all = np.array(meth_val_all)
means = np.array([[np.mean(meth_val_all[0]),np.mean(meth_val_all[1]),np.mean(meth_val_all[2])]])

meth_val_fin = np.hstack((meth_val_all, np.transpose(means)))
fig, ax = plt.subplots()
im = ax.imshow(meth_val_fin, cmap = 'Reds', vmin=0.5, vmax=1)
cbaxes = fig.add_axes([0.07, 0.25, 0.01, 0.5])  # This is the position for the colorbar
fig.colorbar(im, cax=cbaxes, shrink=0.45, aspect = 10)

fn=14
fig.set_figwidth(16)
fig.set_figwidth(16)
nc = len(meth)
ax.set_xticks(np.arange(nc))
ax.set_yticks(np.arange(3))

# Loop over data dimensions and create text annotations.
for i in range(3):
    for j in range(nc):
        text = ax.text(j, i, format(meth_val_fin[i, j], '.2f'), ha="center", va="center", color='k')

ax.set_title(name_tech, fontsize = fn+2)
ax.tick_params(labelsize = fn)
ax.set_xticklabels([meth[cl] for cl in range(nc)], rotation = 90)
ax.set_yticklabels(list_meth_lab, rotation =0)
ax.yaxis.set_label_position("right")
ax.yaxis.tick_right()

# %%
fold_model = 'RBM'
sheet_names=[]
for pp in [1,2,4,6]:
    sheet_names.append(fold_model + '_pat_' + str(pp) + '_pairwise')
        
file = pd.read_excel(rootf + '/Data/Specificity_tables/summary_aurocs.xlsx', sheet_name = sheet_names)

# %%
## Visualization of pairwise AUROCs (Fig. S5C)##

## pairwise AUC: pt1, pt2 ##
namesa = ['WT', 'NA', 'MUC16ID', 'MUC16WT', 'CR']

fn=14
fig, axes = plt.subplots(1,2)
fig.set_figheight(5)
fig.set_figwidth(11)
fig.subplots_adjust(left=0.2, bottom=0.4)
t=0
for pp in [1,2]:
    file1 = file[fold_model + '_pat_' + str(pp) + '_pairwise']
    auroc = np.array(file1)
    nc=len(auroc)
    ax = axes[t]
    im = ax.imshow(auroc, cmap = 'twilight_shifted')

    ax.set_xticks(np.arange(nc))
    ax.set_yticks(np.arange(nc))

    # Loop over data dimensions and create text annotations.
    for i in range(nc):
        for j in range(nc):
            if i!=j:
                text = ax.text(j, i, format(auroc[i, j], '.2f'), ha="center", va="center", color="w")

    ax.set_title('Pairwise AUROC Pt ' + str(t+1), fontsize = fn)
    ax.tick_params(labelsize = fn)
    ax.set_xticklabels([namesa[cl] for cl in range(nc)], rotation = 35)
    ax.set_yticklabels([namesa[cl] for cl in range(nc)], rotation =35)
    t+=1

# %%
## pairwise AUC: pt4, pt6 ##
namesa = [['WT', 'NA', 'CR'],['NA1', 'NA2', 'CR1', 'CR2']]

fn=14
fig, axes = plt.subplots(1,2)
fig.set_figheight(4)
fig.set_figwidth(9)
fig.subplots_adjust(left=0.2, bottom=0.4)
t=0
for pp in [4,6]:
    file1 = file[fold_model + '_pat_' + str(pp) + '_pairwise']
    auroc = np.array(file1)
    nc=len(auroc)
    ax = axes[t]
    im = ax.imshow(auroc, cmap = 'twilight_shifted')

    ax.set_xticks(np.arange(nc))
    ax.set_yticks(np.arange(nc))

    # Loop over data dimensions and create text annotations.
    for i in range(nc):
        for j in range(nc):
            if i!=j:
                text = ax.text(j, i, format(auroc[i, j], '.2f'), ha="center", va="center", color="w")

    ax.set_title('Pairwise AUROC Pt ' + str(t+1), fontsize = fn)
    ax.tick_params(labelsize = fn)
    ax.set_xticklabels([namesa[r][cl] for cl in range(nc)], rotation = 35)
    ax.set_yticklabels([namesa[r][cl] for cl in range(nc)], rotation =35)
    t+=1
